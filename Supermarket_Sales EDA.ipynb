# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales=pd.read_csv('supermarket_sales.csv')
sales
# Out:
#      Invoice _ID Branch       City Customer_ type  Gender  \
# 0    750-67-8428      A     Yangon         Member  Female
# 1    226-31-3081      C  Naypyitaw         Normal  Female
# 2    631-41-3108      A     Yangon         Normal    Male
# 3    123-19-1176      A     Yangon         Member    Male
# 4    373-73-7910      A     Yangon         Normal    Male
# ..           ...    ...        ...            ...     ...
# 995  233-67-5758      C  Naypyitaw         Normal    Male
# 996  303-96-2227      B   Mandalay         Normal  Female
# 997  727-02-1313      A     Yangon         Member    Male
# 998  347-56-2442      A     Yangon         Normal    Male
# 999  849-09-3807      A     Yangon         Member  Female
#
#               Product _line  Unit _price  Quantity   Tax 5%      Total  \
# 0         Health and beauty        74.69         7  26.1415   548.9715
# 1    Electronic accessories        15.28         5   3.8200    80.2200
# ...

# %%
#print the name of the columns present in the dataset
for cols in sales.columns:
    print(cols)
# Out:
# Invoice _ID
# Branch
# City
# Customer_ type
# Gender
# Product _line
# Unit _price
# Quantity
# Tax 5%
# Total
# Date
# Time
# Payment
# cogs
# gross _margin_ percentage
# gross _income
# Rating

# %%
sales.head()
# Out:
#    Invoice _ID Branch       City Customer_ type  Gender  \
# 0  750-67-8428      A     Yangon         Member  Female
# 1  226-31-3081      C  Naypyitaw         Normal  Female
# 2  631-41-3108      A     Yangon         Normal    Male
# 3  123-19-1176      A     Yangon         Member    Male
# 4  373-73-7910      A     Yangon         Normal    Male
#
#             Product _line  Unit _price  Quantity   Tax 5%     Total  \
# 0       Health and beauty        74.69         7  26.1415  548.9715
# 1  Electronic accessories        15.28         5   3.8200   80.2200
# 2      Home and lifestyle        46.33         7  16.2155  340.5255
# 3       Health and beauty        58.22         8  23.2880  489.0480
# 4       Sports and travel        86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross _margin_ percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                   4.761905
# 1  03-08-2019  10:29         Cash   76.40                   4.761905
# ...

# %%
#how many rows and columns are there in the dataset
sales.shape
# Out:
# (1000, 17)

# %%
#describe the dataset
sales.describe()
# Out:
#        Unit _price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross _margin_ percentage  gross _income      Rating
# count               1.000000e+03    1000.000000  1000.00000
# mean                4.761905e+00      15.379369     6.97270
# std                 6.131498e-14      11.708825     1.71858
# min                 4.761905e+00       0.508500     4.00000
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Invoice _ID                1000 non-null   object
#  1   Branch                     1000 non-null   object
#  2   City                       1000 non-null   object
#  3   Customer_ type             1000 non-null   object
#  4   Gender                     1000 non-null   object
#  5   Product _line              1000 non-null   object
#  6   Unit _price                1000 non-null   float64
#  7   Quantity                   1000 non-null   int64
#  8   Tax 5%                     1000 non-null   float64
#  9   Total                      1000 non-null   float64
#  10  Date                       1000 non-null   object
#  11  Time                       1000 non-null   object
#  12  Payment                    1000 non-null   object
# ...

# %%
#the maximum cogs 
sales[sales['cogs']==sales['cogs'].max()]
# Out:
#      Invoice _ID Branch       City Customer_ type  Gender  \
# 350  860-79-0874      C  Naypyitaw         Member  Female
#
#            Product _line  Unit _price  Quantity  Tax 5%    Total       Date  \
# 350  Fashion accessories         99.3        10   49.65  1042.65  2/15/2019
#
#       Time      Payment   cogs  gross _margin_ percentage  gross _income  \
# 350  14:53  Credit card  993.0                   4.761905          49.65
#
#      Rating
# 350     6.6

# %%
sales[sales['cogs']==sales['cogs'].min()]
# Out:
#      Invoice _ID Branch       City Customer_ type Gender      Product _line  \
# 822  784-21-9238      C  Naypyitaw         Member   Male  Sports and travel
#
#      Unit _price  Quantity  Tax 5%    Total        Date   Time Payment   cogs  \
# 822        10.17         1  0.5085  10.6785  02-07-2019  14:15    Cash  10.17
#
#      gross _margin_ percentage  gross _income  Rating
# 822                   4.761905         0.5085     5.9

# %%
#who has bought the most products in an city

sales['City'].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
#LETS PLOT THIS IN AN GRAPH
x=list(sales['City'].value_counts().keys())
y=list(sales['City'].value_counts())

plt.bar(x,y)
plt.xlabel('City')
plt.ylabel('Number of sales')
# Out:
# Text(0, 0.5, 'Number of sales')

# %%
sns.histplot(x='Unit _price',bins=20,data=sales,kde=False)
plt.title('Distribution of unit price')
# Out:
# Text(0.5, 1.0, 'Distribution of unit price')

# %%
#lets see which gender has spent the most in each city
sns.barplot(x='City',y='Total',data=sales,hue='Gender')
# Out:
# <AxesSubplot:xlabel='City', ylabel='Total'>

# %%
#find the unique customer type and the frequency of the each type
sales['Customer_ type'].unique()
sales['Customer_ type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer_ type, dtype: int64

# %%
#Lets plot which customer_type has bought the most products
sns.countplot('Customer_ type',data=sales)
# Out:
# <AxesSubplot:xlabel='Customer_ type', ylabel='count'>

# %%
#the total sales of all the products
total_sales=sales['Total'].sum()
total_sales
# Out:
# 322966.749

# %%
#City with the most sales 
city_with_highest_sales = sales.loc[sales['Total'].idxmax(), 'City']
city_with_highest_sales
# Out:
# 'Naypyitaw'

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='Product _line',y='Unit _price',data=sales,hue='City')
# Out:
# <AxesSubplot:xlabel='Product _line', ylabel='Unit _price'>

# %%
#the frequency of payments done
sales['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
#lets plot this in an pie graph
plt.pie(list(sales['Payment'].value_counts()),labels=list(sales['Payment'].value_counts().keys()),autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1fef3016ee0>,
# ...
#  [Text(0.5147227993273717, 0.9721421911698896, 'Ewallet'),
#   Text(-1.093730866010994, -0.11727230165235786, 'Cash'),
#   Text(0.6154305139598073, -0.9117265393127303, 'Credit card')],
#  [Text(0.28075789054220274, 0.530259377001758, '34.5%'),
#   Text(-0.596580472369633, -0.06396670999219518, '34.4%'),
#   Text(0.33568937125080395, -0.49730538507967104, '31.1%')])

# %%
#THE FREQUENCY OF TIME the products has be bought
sales['Time'].value_counts().head(10)
# Out:
# 19:48    7
# 14:42    7
# 17:38    6
# 17:16    5
# 11:40    5
# 13:48    5
# 19:39    5
# 19:20    5
# 17:36    5
# 13:58    5
# Name: Time, dtype: int64

# %%
sales['Date'].value_counts().head(10)
# Out:
# 02-07-2019    20
# 2/15/2019     19
# 3/14/2019     18
# 03-02-2019    18
# 01-08-2019    18
# 1/26/2019     17
# 1/25/2019     17
# 1/23/2019     17
# 03-05-2019    17
# 3/19/2019     16
# Name: Date, dtype: int64

# %%
#product which has the highest rating given in each city

plt.figure(figsize=(15,15))
sns.barplot(x='Product _line',y='Rating',data=sales,hue='City')
# Out:
# <AxesSubplot:xlabel='Product _line', ylabel='Rating'>

# %%
#product which has the most gross_income given in each city

plt.figure(figsize=(15,15))
sns.barplot(x='Product _line',y='gross _income',data=sales,hue='City')
# Out:
# <AxesSubplot:xlabel='Product _line', ylabel='gross _income'>

# %%
#product which has highest number of total_sales  in each city

plt.figure(figsize=(15,15))
sns.barplot(x='Product _line',y='Total',data=sales,hue='City')
# Out:
# <AxesSubplot:xlabel='Product _line', ylabel='Total'>

# %%
sales.groupby('Product _line')['Quantity'].sum()
# Out:
# Product _line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: Quantity, dtype: int64

# %%
sales.groupby(['Product _line','City'])['Quantity'].sum()
# Out:
# Product _line           City
# Electronic accessories  Mandalay     316
#                         Naypyitaw    333
#                         Yangon       322
# Fashion accessories     Mandalay     297
#                         Naypyitaw    342
#                         Yangon       263
# Food and beverages      Mandalay     270
#                         Naypyitaw    369
#                         Yangon       313
# Health and beauty       Mandalay     320
#                         Naypyitaw    277
#                         Yangon       257
# Home and lifestyle      Mandalay     295
#                         Naypyitaw    245
#                         Yangon       371
# Sports and travel       Mandalay     322
#                         Naypyitaw    265
#                         Yangon       333
# Name: Quantity, dtype: int64

# %%
sales.corr()
# Out:
#                            Unit _price  Quantity    Tax 5%     Total  \
# Unit _price                   1.000000  0.010778  0.633962  0.633962
# Quantity                      0.010778  1.000000  0.705510  0.705510
# Tax 5%                        0.633962  0.705510  1.000000  1.000000
# Total                         0.633962  0.705510  1.000000  1.000000
# cogs                          0.633962  0.705510  1.000000  1.000000
# gross _margin_ percentage          NaN       NaN       NaN       NaN
# gross _income                 0.633962  0.705510  1.000000  1.000000
# Rating                       -0.008778 -0.015815 -0.036442 -0.036442
#
#                                cogs  gross _margin_ percentage  gross _income  \
# Unit _price                0.633962                        NaN       0.633962
# Quantity                   0.705510                        NaN       0.705510
# Tax 5%                     1.000000                        NaN       1.000000
# ...

# %%
sns.heatmap(sales.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>
